# %%
import qiskit

# %%
qiskit.__version__
# Out:
# '2.0.0'

# %%
from qiskit_ibm_runtime import QiskitRuntimeService
service = QiskitRuntimeService.save_account(
    channel="ibm_cloud", # `channel` distinguishes between different account types
    token="3uVL3LEGVn_CCpc2sF-n65zb6eW15MfH8FbDWYfxiWjv", # Your token is confidential.
    # Do not share your key in public code.
    instance="crn:v1:bluemix:public:quantum-computing:us-east:a/939248846bf94b528bfc0225b44e76a5:534d673c-b784-476f-bc02-e9bd9009595e::",
    name="learning", # Optionally name this set of account credentials.
    set_as_default=True, # Optionally set these as your default credentials.
)
# Out:
# ---------------------------------------------------------------------------
# AccountAlreadyExistsError                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 from qiskit_ibm_runtime import QiskitRuntimeService
# ----> 2 service = QiskitRuntimeService.save_account(
#       3     channel="ibm_cloud", # `channel` distinguishes between different account types
#       4     token="3uVL3LEGVn_CCpc2sF-n65zb6eW15MfH8FbDWYfxiWjv", # Your token is confidential.
#       5     # Do not share your key in public code.
#       6     instance="crn:v1:bluemix:public:quantum-computing:us-east:a/939248846bf94b528bfc0225b44e76a5:534d673c-b784-476f-bc02-e9bd9009595e::",
#       7     name="learning", # Optionally name this set of account credentials.
#       8     set_as_default=True, # Optionally set these as your default credentials.
#       9 )
#
# ...
